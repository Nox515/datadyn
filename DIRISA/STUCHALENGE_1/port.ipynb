# %%
import pandas as pd

try:
    excel_url = "https://adbdatathon.s3.af-south-1.amazonaws.com/Datathon/Vehicle_Data.xlsx"
    df_excel = pd.read_exce(excel_url)
